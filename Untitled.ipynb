# %%
import pandas as pd

# %%
df1 = pd.read_csv("twitter_parsed_dataset.csv")

# %%
df2 = pd.read_csv("twitter_racism_parsed_dataset.csv")

# %%
pd.concat([df1,df2])
# Out:
#                        index                     id  \
# 0      5.74948705591165E+017  5.74948705591165E+017
# 1      5.71917888690393E+017  5.71917888690393E+017
# 2      3.90255841338601E+017  3.90255841338601E+017
# 3      5.68208850655916E+017  5.68208850655916E+017
# 4      5.75596338802373E+017  5.75596338802373E+017
# ...                      ...                    ...
# 13466            5.75596e+17            5.75596e+17
# 13467            5.58063e+17            5.58063e+17
# 13468            5.75597e+17            5.75597e+17
# 13469            5.75599e+17            5.75599e+17
# 13470            5.75598e+17            5.75598e+17
#
#                                                     Text Annotation  oh_label
# 0      @halalflaws @biebervalue @greenlinerzjm I read...       none       0.0
# 1      @ShreyaBafna3 Now you idiots claim that people...       none       0.0
# 2      RT @Mooseoftorment Call me sexist, but when I ...     sexism       1.0
# ...
